# %%
import plotly.io as pio

pio.renderers.default = "vscode+jupyterlab+notebook_connected"

# %% [markdown]
# # Project 3

# %% [markdown]
# The Right to Know Act, passed in New York City in 2018, promotes transparency and accountability in NYPD interactions with the public. It requires officers to identify themselves and provide business cards during investigatory stops and to obtain clear, informed consent for non-warranted searches, explaining individuals' right to refuse.
#
# In this project, I will look at data to test the hypothesis of whether the Act has been associated with changes in trends of complaints against police officers, particularly whether it increased overall complaints and especially substantiated complaints against police officers.
#
# I will use this data from the "NYCLU NYPD Misconduct Complaint Database"
# https://github.com/new-york-civil-liberties-union/NYPD-Misconduct-Complaint-Database-Updated

# %% [markdown]
# - **Dataset(s) to be used:** [[NYCLU NYPD Misconduct Complaint Database](https://github.com/new-york-civil-liberties-union/NYPD-Misconduct-Complaint-Database-Updated)]
# - **Analysis question:** [Did the Right to Know Act affect the trend of residents' complaints against the police]
# - **Columns that will (likely) be used:**
#   - [IncidentDate]
#   - [FADOType]
#   - [BoardCat]
# - **Hypothesis**: [the Act has been associated with changes in trends of complaints against police officers, particularly whether it increased overall complaints and especially substantiated complaints against police officers. ]
# - **Site URL:**
# [[Readthedocs](https://github.com/3ngri/computing-in-context/commit/13c3cae636a399ffc2cf9985dda253a0e13a04f1)]

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# I'm going to load the dataset first.
#
# I'm going to use it to look at the trend of complaints (incidents) a few years before and after the act to analyze the trend.
#
# I will also look at how the types of complaints changed over that period

# %%
complaints = pd.read_csv("CCRB Complaint Database Raw 04.28.2023.csv")

complaints.head()
# Out:
# C:\Users\alang\AppData\Local\Temp\ipykernel_27676\147524999.py:1: DtypeWarning:
#
# Columns (23,25,26,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#      AsOfDate  AllegationID LastName FirstName OfficerRace OfficerGender  \
# 0  2023-04-28      240282.0   Wright    Curtis       Black          Male
# 1  2023-04-28      240280.0   Wright    Curtis       Black          Male
# 2  2023-04-28      240281.0   Wright    Curtis       Black          Male
# 3  2023-04-28      240284.0   Rhoden      Kyle       Black          Male
# 4  2023-04-28      240283.0   Rhoden      Kyle       Black          Male
#
#     TaxID CurrentRank CurrentRankLong CurrentCommand  ... PenaltyDesc  \
# 0  895008         POM  Police Officer        114 PCT  ...         NaN
# 1  895008         POM  Police Officer        114 PCT  ...         NaN
# 2  895008         POM  Police Officer        114 PCT  ...         NaN
# 3  899750         POM  Police Officer        MED DIV  ...         NaN
# 4  899750         POM  Police Officer        MED DIV  ...         NaN
#
#      LocationType                                 ContactReason  \
# 0  Street/highway  PD suspected C/V of violation/crime - street
# 1  Street/highway  PD suspected C/V of violation/crime - street
# 2  Street/highway  PD suspected C/V of violation/crime - street
# 3  Street/highway  PD suspected C/V of violation/crime - street
# 4  Street/highway  PD suspected C/V of violation/crime - street
#
#    ContactOutcome  IncidentPrecinct ImpactedRace ImpactedGender  ImpactedAge  \
# 0             NaN           PCT 114          NaN            NaN          NaN
# 1             NaN           PCT 114        Black       Male/Man         24.0
# 2             NaN           PCT 114        Black       Male/Man         24.0
# 3             NaN           PCT 114        Black       Male/Man         24.0
# 4             NaN           PCT 114        Black       Male/Man         24.0
#
#   ReceivedDate   CloseDate
# 0   2000-01-03  2000-05-26
# 1   2000-01-03  2000-05-26
# 2   2000-01-03  2000-05-26
# 3   2000-01-03  2000-05-26
# 4   2000-01-03  2000-05-26
#
# [5 rows x 35 columns]

# %%
#Checking types of columns I'm interested in 

complaints.dtypes
# Out:
# AsOfDate             object
# AllegationID        float64
# LastName             object
# FirstName            object
# OfficerRace          object
# OfficerGender        object
# TaxID                 int64
# CurrentRank          object
# CurrentRankLong      object
# CurrentCommand       object
# IncidentRank         object
# IncidentRankLong     object
# IncidentCommand      object
# ShieldNo              int64
# DaysOnForce           int64
# Status               object
# LastActive           object
# ComplaintID           int64
# IncidentDate         object
# FADOType             object
# Allegation           object
# CCRBDisposition      object
# BoardCat             object
# PenaltyRec           object
# PenaltyCat           object
# PenaltyDesc          object
# LocationType         object
# ContactReason        object
# ContactOutcome       object
# IncidentPrecinct     object
# ImpactedRace         object
# ImpactedGender       object
# ImpactedAge         float64
# ReceivedDate         object
# CloseDate            object
# dtype: object

# %% [markdown]
# I see that incident date is an object. I want to make a date to be able to filter it properly

# %%
complaints["IncidentDate"] = pd.to_datetime(complaints["IncidentDate"], format = "%Y-%m-%d")

complaints["IncidentDate"].head
# Out:
# <bound method NDFrame.head of 0        2000-01-01
# 1        2000-01-01
# 2        2000-01-01
# 3        2000-01-01
# 4        2000-01-01
#             ...
# 302796   1999-12-30
# 302797   1999-11-28
# 302798   1999-12-02
# 302799   1998-11-11
# 302800   1998-11-11
# Name: IncidentDate, Length: 302801, dtype: datetime64[ns]>

# %% [markdown]
# I will now narrow down the data to the years I'm interested in. Since the act was passed in 2018. I will look at 5 years before the act and 5 years after

# %%
filtered_complaints = complaints[
    (complaints["IncidentDate"] > "2013-01-01") & 
    (complaints["IncidentDate"] < "2023-12-31")
]

filtered_complaints.head()
# Out:
#           AsOfDate  AllegationID LastName FirstName OfficerRace OfficerGender  \
# 120262  2023-04-28      810200.0  Kozicki    Lukasz       White          Male
# 120277  2023-04-28      825595.0    Paley  Benjamin       White          Male
# 120278  2023-04-28      809890.0     Dunn    Thomas    Hispanic          Male
# 120279  2023-04-28      810020.0     Dunn    Thomas    Hispanic          Male
# 120280  2023-04-28      809899.0   Doheny     James       White          Male
#
#          TaxID CurrentRank CurrentRankLong CurrentCommand  ... PenaltyDesc  \
# 120262  945887         POM  Police Officer        TB DT34  ...  No penalty
# 120277  951000         SGT        Sergeant            IAB  ...         NaN
# 120278  950356         DTS       Detective        INT SDU  ...         NaN
# 120279  950356         DTS       Detective        INT SDU  ...         NaN
# 120280  950336         DT3       Detective        NARCBMN  ...         NaN
#
#                 LocationType                                 ContactReason  \
# 120262  Subway station/train  PD suspected C/V of violation/crime - subway
# 120277        Street/highway                              Moving violation
# 120278        Street/highway                              Moving violation
# 120279        Street/highway                              Moving violation
# 120280        Street/highway                              Moving violation
#
#                          ContactOutcome  IncidentPrecinct ImpactedRace  \
# 120262  Summons - other violation/crime           PCT 066     Hispanic
# 120277        Arrest - resisting arrest           PCT 025        Black
# 120278        Arrest - resisting arrest           PCT 025        Black
# 120279        Arrest - resisting arrest           PCT 025        Black
# 120280        Arrest - resisting arrest           PCT 025        Black
#
#        ImpactedGender  ImpactedAge ReceivedDate   CloseDate
# 120262       Male/Man         34.0   2013-01-03  2013-10-04
# 120277       Male/Man         39.0   2013-01-06  2014-07-09
# 120278       Male/Man         39.0   2013-01-06  2014-07-09
# 120279       Male/Man         39.0   2013-01-06  2014-07-09
# 120280       Male/Man         39.0   2013-01-06  2014-07-09
#
# [5 rows x 35 columns]

# %% [markdown]
# Now, I need to aggregate the data to count the rows for each day. I will use the resample function

# %%
total_complaints = filtered_complaints.resample('D', on="IncidentDate").size().reset_index(name="Count")

total_complaints.head()
# Out:
#   IncidentDate  Count
# 0   2013-01-02     10
# 1   2013-01-03      8
# 2   2013-01-04     10
# 3   2013-01-05     10
# 4   2013-01-06      5

# %% [markdown]
# I want to start by analyzing the overall trends first

# %%
fig1 = px.line(
    total_complaints,
    x = "IncidentDate",
    y = "Count",
    title="Total count of incidents"
)

fig1.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="a5a79aa2-8b87-4c8c-94b5-916a40ae6598" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5a79aa2-8b87-4c8c-94b5-916a40ae6598")) {                    Plotly.newPlot(                        "a5a79aa2-8b87-4c8c-94b5-916a40ae6598",                        [{"hovertemplate":"IncidentDate=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-01-02T00:00:00","2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-05T00:00:00","2013-01-06T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-12T00:00:00","2013-01-13T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-19T00:00:00","2013-01-20T00:00:00","2013-01-21T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-26T00:00:00","2013-01-27T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-02T00:00:00","2013-02-03T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-09T00:00:00","2013-02-10T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-16T00:00:00","2013-02-17T00:00:00","2013-02-18T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-23T00:00:00","2013-02-24T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02-27T00:00:00","2013-02-28T00:00:00","2013-03-01T00:00:00","2013-03-02T00:00:00","2013-03-03T00:00:00","2013-03-04T00:00:00","2013-03-05T00:00:00","2013-03-06T00:00:00","2013-03-07T00:00:00","2013-03-08T00:00:00","2013-03-09T00:00:00","2013-03-10T00:00:00","2013-03-11T00:00:00","2013-03-12T00:00:00","2013-03-13T00:00:00","2013-03-14T00:00:00","2013-03-15T00:00:00","2013-03-16T00:00:00","2013-03-17T00:00:00","2013-03-18T00:00:00","2013-03-19T00:00:00","2013-03-20T00:00:00","2013-03-21T00:00:00","2013-03-22T00:00:00","2013-03-23T00:00:00","2013-03-24T00:00:00","2013-03-25T00:00:00","2013-03-26T00:00:00","2013-03-27T00:00:00","2013-03-28T00:00:00","2013-03-29T00:00:00","2013-03-30T00:00:00","2013-03-31T00:00:00","2013-04-01T00:00:00","2013-04-02T00:00:00","2013-04-03T00:00:00","2013-04-04T00:00:00","2013-04-05T00:00:00","2013-04-06T00:00:00","2013-04-07T00:00:00","2013-04-08T00:00:00","2013-04-09T00:00:00","2013-04-10T00:00:00","2013-04-11T00:00:00","2013-04-12T00:00:00","2013-04-13T00:00:00","2013-04-14T00:00:00","2013-04-15T00:00:00","2013-04-16T00:00:00","2013-04-17T00:00:00","2013-04-18T00:00:00","2013-04-19T00:00:00","2013-04-20T00:00:00","2013-04-21T00:00:00","2013-04-22T00:00:00","2013-04-23T00:00:00","2013-04-24T00:00:00","2013-04-25T00:00:00","2013-04-26T00:00:00","2013-04-27T00:00:00","2013-04-28T00:00:00","2013-04-29T00:00:00","2013-04-30T00:00:00","2013-05-01T00:00:00","2013-05-02T00:00:00","2013-05-03T00:00:00","2013-05-04T00:00:00","2013-05-05T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-11T00:00:00","2013-05-12T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-18T00:00:00","2013-05-19T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-25T00:00:00","2013-05-26T00:00:00","2013-05-27T00:00:00","2013-05-28T00:00:0 ...

# %% [markdown]
# This is not easy to read. I'll resample by month instead and try again

# %%
total_complaints_monthly = filtered_complaints.resample('M', on="IncidentDate").size().reset_index(name="Count")


fig2 = px.line(
    total_complaints_monthly,
    x = "IncidentDate",
    y = "Count",
    title="Total count of incidents"
)

fig2.show()
# Out:
# C:\Users\alang\AppData\Local\Temp\ipykernel_27676\3114287050.py:1: FutureWarning:
#
# 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
# <div>                            <div id="aeb9ae45-caad-430f-9915-f66f37b6be80" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aeb9ae45-caad-430f-9915-f66f37b6be80")) {                    Plotly.newPlot(                        "aeb9ae45-caad-430f-9915-f66f37b6be80",                        [{"hovertemplate":"IncidentDate=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2013-01-31T00:00:00","2013-02-28T00:00:00","2013-03-31T00:00:00","2013-04-30T00:00:00","2013-05-31T00:00:00","2013-06-30T00:00:00","2013-07-31T00:00:00","2013-08-31T00:00:00","2013-09-30T00:00:00","2013-10-31T00:00:00","2013-11-30T00:00:00","2013-12-31T00:00:00","2014-01-31T00:00:00","2014-02-28T00:00:00","2014-03-31T00:00:00","2014-04-30T00:00:00","2014-05-31T00:00:00","2014-06-30T00:00:00","2014-07-31T00:00:00","2014-08-31T00:00:00","2014-09-30T00:00:00","2014-10-31T00:00:00","2014-11-30T00:00:00","2014-12-31T00:00:00","2015-01-31T00:00:00","2015-02-28T00:00:00","2015-03-31T00:00:00","2015-04-30T00:00:00","2015-05-31T00:00:00","2015-06-30T00:00:00","2015-07-31T00:00:00","2015-08-31T00:00:00","2015-09-30T00:00:00","2015-10-31T00:00:00","2015-11-30T00:00:00","2015-12-31T00:00:00","2016-01-31T00:00:00","2016-02-29T00:00:00","2016-03-31T00:00:00","2016-04-30T00:00:00","2016-05-31T00:00:00","2016-06-30T00:00:00","2016-07-31T00:00:00","2016-08-31T00:00:00","2016-09-30T00:00:00","2016-10-31T00:00:00","2016-11-30T00:00:00","2016-12-31T00:00:00","2017-01-31T00:00:00","2017-02-28T00:00:00","2017-03-31T00:00:00","2017-04-30T00:00:00","2017-05-31T00:00:00","2017-06-30T00:00:00","2017-07-31T00:00:00","2017-08-31T00:00:00","2017-09-30T00:00:00","2017-10-31T00:00:00","2017-11-30T00:00:00","2017-12-31T00:00:00","2018-01-31T00:00:00","2018-02-28T00:00:00","2018-03-31T00:00:00","2018-04-30T00:00:00","2018-05-31T00:00:00","2018-06-30T00:00:00","2018-07-31T00:00:00","2018-08-31T00:00:00","2018-09-30T00:00:00","2018-10-31T00:00:00","2018-11-30T00:00:00","2018-12-31T00:00:00","2019-01-31T00:00:00","2019-02-28T00:00:00","2019-03-31T00:00:00","2019-04-30T00:00:00","2019-05-31T00:00:00","2019-06-30T00:00:00","2019-07-31T00:00:00","2019-08-31T00:00:00","2019-09-30T00:00:00","2019-10-31T00:00:00","2019-11-30T00:00:00","2019-12-31T00:00:00","2020-01-31T00:00:00","2020-02-29T00:00:00","2020-03-31T00:00:00","2020-04-30T00:00:00","2020-05-31T00:00:00","2020-06-30T00:00:00","2020-07-31T00:00:00","2020-08-31T00:00:00","2020-09-30T00:00:00","2020-10-31T00:00:00","2020-11-30T00:00:00","2020-12-31T00:00:00","2021-01-31T00:00:00","2021-02-28T00:00:00","2021-03-31T00:00:00","2021-04-30T00:00:00","2021-05-31T00:00:00","2021-06-30T00:00:00","2021-07-31T00:00:00","2021-08-31T00:00:00","2021-09-30T00:00:00","2021-10-31T00:00:00","2021-11-30T00:00:00","2021-12-31T00:00:00","2022-01-31T00:00:00","2022-02-28T00:00:00","2022-03-31T00:00:00","2022-04-30T00:00:00","2022-05-31T00:00:00","2022-06-30T00:00:00","2022-07-31T00:00:00","2022-08-31T00:00:00","2022-09-30T00:00:00","2022-10-31T00:00:00","2022-11-30T00:00:00","2022-12-31T00:00:00","2023-01-31T00:00:00","2023-02-28T00:00:00","2023-03-31T00:00:00"],"xaxis":"x","y":[498,529,754,685,789,679,731,691,685,743,740,504,717,621,700,639,756,806,673,625,569,518,427,355,362,464,605,557,608,687,663,734,754,790,532,576,713,757,797,722,697,711,716,668,633,567,563,526,671,678,791,838,702,793,759,772,679,726,580,583,739,650,788,733,859,636,821,1036,801,921,877,761,1076,898,972,960,990,1091,1167,1062,783,740,656,732,948,1029,1082,1061,1765,1132,379,495,628,703,725,785,978,862,1092,446,878,669,713,739,833,928,636,487,314,228,265,131,195,177,202,179,130,178,164,10 ...

# %% [markdown]
# Interesting. There seems to be more complaints the 2 years following the act. Then (ignoring the fluctuations aronud covid period) it seems to go down after 2021.
#
# I'm interested to see how the trend is by each type of complaint.

# %%
# Extract the month from IncidentDate for grouping
filtered_complaints["Month"] = filtered_complaints["IncidentDate"].dt.to_period("M")

# Convert it back to a datetime for plotting
filtered_complaints["Month"] = filtered_complaints["Month"].dt.to_timestamp()

# Group by 'Month' and 'FADOType' and count complaints
monthly_complaints_bytype = (
    filtered_complaints
    .groupby(["Month", "FADOType"])
    .size()
    .reset_index(name="Count")
)



monthly_complaints_bytype.head()
# Out:
# C:\Users\alang\AppData\Local\Temp\ipykernel_27676\2128349939.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\alang\AppData\Local\Temp\ipykernel_27676\2128349939.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        Month            FADOType  Count
# 0 2013-01-01  Abuse of Authority    224
# 1 2013-01-01         Discourtesy     93
# 2 2013-01-01               Force    163
# 3 2013-01-01  Offensive Language     18
# 4 2013-02-01  Abuse of Authority    242

# %% [markdown]
# Using that, I'll try plotting it again showing lines for each type of complaints.

# %%
fig3 = px.line(
    monthly_complaints_bytype,
    x="Month",
    y="Count",
    color="FADOType",  
    title="Monthly Complaints by Type"
)

fig3.show()
# Out:
# <div>                            <div id="348013b7-1b40-46b4-a176-de3a417edb6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("348013b7-1b40-46b4-a176-de3a417edb6f")) {                    Plotly.newPlot(                        "348013b7-1b40-46b4-a176-de3a417edb6f",                        [{"hovertemplate":"FADOType=Abuse of Authority\u003cbr\u003eMonth=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Abuse of Authority","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Abuse of Authority","orientation":"v","showlegend":true,"x":["2013-01-01T00:00:00","2013-02-01T00:00:00","2013-03-01T00:00:00","2013-04-01T00:00:00","2013-05-01T00:00:00","2013-06-01T00:00:00","2013-07-01T00:00:00","2013-08-01T00:00:00","2013-09-01T00:00:00","2013-10-01T00:00:00","2013-11-01T00:00:00","2013-12-01T00:00:00","2014-01-01T00:00:00","2014-02-01T00:00:00","2014-03-01T00:00:00","2014-04-01T00:00:00","2014-05-01T00:00:00","2014-06-01T00:00:00","2014-07-01T00:00:00","2014-08-01T00:00:00","2014-09-01T00:00:00","2014-10-01T00:00:00","2014-11-01T00:00:00","2014-12-01T00:00:00","2015-01-01T00:00:00","2015-02-01T00:00:00","2015-03-01T00:00:00","2015-04-01T00:00:00","2015-05-01T00:00:00","2015-06-01T00:00:00","2015-07-01T00:00:00","2015-08-01T00:00:00","2015-09-01T00:00:00","2015-10-01T00:00:00","2015-11-01T00:00:00","2015-12-01T00:00:00","2016-01-01T00:00:00","2016-02-01T00:00:00","2016-03-01T00:00:00","2016-04-01T00:00:00","2016-05-01T00:00:00","2016-06-01T00:00:00","2016-07-01T00:00:00","2016-08-01T00:00:00","2016-09-01T00:00:00","2016-10-01T00:00:00","2016-11-01T00:00:00","2016-12-01T00:00:00","2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00","2022-07-01T00:00:00","2022-08-01T00:00:00","2022-09-01T00:00:00","2022-10-01T00:00:00","2022-11-01T00:00:00","2022-12-01T00:00:00","2023-01-01T00:00:00","2023-02-01T00:00:00","2023-03-01T00:00:00"],"xaxis":"x","y":[224,242,344,363,393,345,331,286,306,368,380,267,364,334,302,334,356,370,300,297,264,247,209,179,202,243,301,266,306,326,314,402,377,433,292,328,394,464,432,381,382,337,365,392,348,303,300,288,381,357,516,491,376,468,448,448,379,476,359,356,414,373,479,466,523,377,449,626,498,582,536,459,751,566,631,609,599,644,628,619,464,470,444,386,613,723,682,629,914,490,252,317,412,485,463,522,638,561,703,276,540,414,447,455,464, ...

# %% [markdown]
# It's interesting to see that throughout the period of analysis, Abuse of Authority has the highest share of complaints.
# That being said, in 2022, most of the decline in complaints that we saw the pervious chart seems now to be from the same category. While other categories seem mostly consistent.

# %% [markdown]
# Next, I want to see the trends by ruling/finding that resolved the complaint, by looking at the column BoradCat

# %%
# Group by 'Month' and 'BoardCat' and count complaints
monthly_complaints_decision = (
    filtered_complaints
    .groupby(["Month", "BoardCat"])
    .size()
    .reset_index(name="Count")
)



monthly_complaints_decision.head()
# Out:
#        Month       BoardCat  Count
# 0 2013-01-01     Exonerated     99
# 1 2013-01-01  Miscellaneous      9
# 2 2013-01-01  Substantiated     26
# 3 2013-01-01      Truncated    158
# 4 2013-01-01      Unfounded     26

# %%
fig4 = px.line(
    monthly_complaints_decision,
    x="Month",
    y="Count",
    color="BoardCat",  
    title="Monthly Complaints by Board Ruling"
)

fig4.show()
# Out:
# <div>                            <div id="0496cd3a-3f09-4927-926c-123300e7ac18" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0496cd3a-3f09-4927-926c-123300e7ac18")) {                    Plotly.newPlot(                        "0496cd3a-3f09-4927-926c-123300e7ac18",                        [{"hovertemplate":"BoardCat=Exonerated\u003cbr\u003eMonth=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Exonerated","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Exonerated","orientation":"v","showlegend":true,"x":["2013-01-01T00:00:00","2013-02-01T00:00:00","2013-03-01T00:00:00","2013-04-01T00:00:00","2013-05-01T00:00:00","2013-06-01T00:00:00","2013-07-01T00:00:00","2013-08-01T00:00:00","2013-09-01T00:00:00","2013-10-01T00:00:00","2013-11-01T00:00:00","2013-12-01T00:00:00","2014-01-01T00:00:00","2014-02-01T00:00:00","2014-03-01T00:00:00","2014-04-01T00:00:00","2014-05-01T00:00:00","2014-06-01T00:00:00","2014-07-01T00:00:00","2014-08-01T00:00:00","2014-09-01T00:00:00","2014-10-01T00:00:00","2014-11-01T00:00:00","2014-12-01T00:00:00","2015-01-01T00:00:00","2015-02-01T00:00:00","2015-03-01T00:00:00","2015-04-01T00:00:00","2015-05-01T00:00:00","2015-06-01T00:00:00","2015-07-01T00:00:00","2015-08-01T00:00:00","2015-09-01T00:00:00","2015-10-01T00:00:00","2015-11-01T00:00:00","2015-12-01T00:00:00","2016-01-01T00:00:00","2016-02-01T00:00:00","2016-03-01T00:00:00","2016-04-01T00:00:00","2016-05-01T00:00:00","2016-06-01T00:00:00","2016-07-01T00:00:00","2016-08-01T00:00:00","2016-09-01T00:00:00","2016-10-01T00:00:00","2016-11-01T00:00:00","2016-12-01T00:00:00","2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-03-01T00:00:00"],"xaxis":"x","y":[99,77,143,95,118,115,126,120,122,108,100,71,97,117,127,86,144,139,90,98,84,86,64,72,64,100,140,105,111,162,134,149,122,130,94,129,161,178,199,145,141,192,167,144,141,136,135,138,147,158,206,226,149,204,174,207,156,182,167,131,215,137,175,150,176,206,196,251,188,241,205,180,265,185,245,212,252,237,271,232,154,135,135,230,201,240,256,272,393,276,82,137,230,217,233,230,222,259,324,125,240,138,112,130,94,72,35,20,2],"yaxis":"y","type":"scatter"},{"hovertemplate":"BoardCat=Miscellaneous\u003cbr\u003eMonth=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Miscellaneous","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Miscellaneous","orientation":"v","showlegend":true," ...

# %% [markdown]
# I'm finding it hard to read this chart.
# I'll try instead to create a bar chart. One bar for 2018 and one for 2022

# %%
# Extract the year for grouping
filtered_complaints["Year"] = filtered_complaints["IncidentDate"].dt.year

# Filter data for 2018 and 2022
selected_years = filtered_complaints[filtered_complaints["Year"].isin([2018, 2022])]
# Out:
# C:\Users\alang\AppData\Local\Temp\ipykernel_27676\1249460987.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
grouped_complaints_selected_years = (
    selected_years
    .groupby(["Year", "BoardCat"])
    .size()
    .reset_index(name="Count")
)


fig5 = px.bar(
    grouped_complaints_selected_years,
    x="Year",
    y="Count",
    color="BoardCat", 
    barmode="group",   
    title="Complaints by BoardCat for 2018 and 2022"
)

fig5.show()
# Out:
# <div>                            <div id="c4661ecb-e1ce-41a9-a515-f5b06a390a5f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4661ecb-e1ce-41a9-a515-f5b06a390a5f")) {                    Plotly.newPlot(                        "c4661ecb-e1ce-41a9-a515-f5b06a390a5f",                        [{"alignmentgroup":"True","hovertemplate":"BoardCat=Closed - Pending Litigation\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Closed - Pending Litigation","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Closed - Pending Litigation","offsetgroup":"Closed - Pending Litigation","orientation":"v","showlegend":true,"textposition":"auto","x":[2018,2022],"xaxis":"x","y":[630,521],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"BoardCat=Exonerated\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Exonerated","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Exonerated","offsetgroup":"Exonerated","orientation":"v","showlegend":true,"textposition":"auto","x":[2018,2022],"xaxis":"x","y":[2320,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"BoardCat=Miscellaneous\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Miscellaneous","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Miscellaneous","offsetgroup":"Miscellaneous","orientation":"v","showlegend":true,"textposition":"auto","x":[2018,2022],"xaxis":"x","y":[77,61],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"BoardCat=Substantiated\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Substantiated","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Substantiated","offsetgroup":"Substantiated","orientation":"v","showlegend":true,"textposition":"auto","x":[2018,2022],"xaxis":"x","y":[853,141],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"BoardCat=Truncated\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Truncated","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Truncated","offsetgroup":"Truncated","orientation":"v","showlegend":true,"textposition":"auto","x":[2018,2022],"xaxis":"x","y":[2808,1281],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"BoardCat=Unfounded\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Unfounded","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Unfounded","offsetgroup":"Unfounded","orientation":"v","showlegend":true,"textposition":"auto","x":[2018,2022],"xaxis":"x","y":[477,46],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"BoardCat=Unsubstantiated\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Unsubstantiated","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Unsubstantiated","offsetgroup":"Unsubstantiated","orientation":"v","showlegend":true,"textposition":"auto","x":[2018,2022],"xaxis":"x","y":[2457,101],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"BoardCat=Within NYPD Guidelines\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Within NYPD Guidelines","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Within NYPD Guidelines","offsetgroup":"Within NYPD Guidelines","orientation":"v","showlegend":true,"textposition":"auto","x":[2022],"xaxis":"x","y":[114],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"o ...

# %% [markdown]
# It's still hard to extract insights. I'll try to get the percentage for each category

# %%
#A new series calculating sum by type, so I can divide by it

total_counts_per_year = grouped_complaints_selected_years.groupby("Year")["Count"].transform("sum")

# A new column for percentage in my existing df
grouped_complaints_selected_years["Percentage"] = (grouped_complaints_selected_years["Count"] / total_counts_per_year) * 100

# %%
#Trying the bar chart again

fig6 = px.bar(
    grouped_complaints_selected_years,
    x="Year",
    y="Percentage",
    color="BoardCat", 
    barmode="group",   
    title="Ratio of Complaints by BoardCat for 2018 and 2022"
)

fig6.show()
# Out:
# <div>                            <div id="5459bad5-b588-4104-91be-f9668a0f19df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5459bad5-b588-4104-91be-f9668a0f19df")) {                    Plotly.newPlot(                        "5459bad5-b588-4104-91be-f9668a0f19df",                        [{"alignmentgroup":"True","hovertemplate":"BoardCat=Closed - Pending Litigation\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Closed - Pending Litigation","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Closed - Pending Litigation","offsetgroup":"Closed - Pending Litigation","orientation":"v","showlegend":true,"textposition":"auto","x":[2018,2022],"xaxis":"x","y":[6.5474953232176265,22.981914424349362],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"BoardCat=Exonerated\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Exonerated","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Exonerated","offsetgroup":"Exonerated","orientation":"v","showlegend":true,"textposition":"auto","x":[2018,2022],"xaxis":"x","y":[24.111411348991894,0.08822232024702249],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"BoardCat=Miscellaneous\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Miscellaneous","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Miscellaneous","offsetgroup":"Miscellaneous","orientation":"v","showlegend":true,"textposition":"auto","x":[2018,2022],"xaxis":"x","y":[0.8002494283932654,2.690780767534186],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"BoardCat=Substantiated\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Substantiated","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Substantiated","offsetgroup":"Substantiated","orientation":"v","showlegend":true,"textposition":"auto","x":[2018,2022],"xaxis":"x","y":[8.865100810642277,6.219673577415086],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"BoardCat=Truncated\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Truncated","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Truncated","offsetgroup":"Truncated","orientation":"v","showlegend":true,"textposition":"auto","x":[2018,2022],"xaxis":"x","y":[29.183122012055705,56.50639611821791],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"BoardCat=Unfounded\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Unfounded","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Unfounded","offsetgroup":"Unfounded","orientation":"v","showlegend":true,"textposition":"auto","x":[2018,2022],"xaxis":"x","y":[4.957389316150489,2.0291133656815177],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"BoardCat=Unsubstantiated\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Unsubstantiated","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Unsubstantiated","offsetgroup":"Unsubstantiated","orientation":"v","showlegend":true,"textposition":"auto","x":[2018,2022],"xaxis":"x","y":[25.535231760548744,4.455227172474636],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"BoardCat=Within NYPD Guidelines\u003cbr\u003eYear=%{x}\u003cbr\u003ePercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Within NYPD Guidelines","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Within NYPD Guidelines","offsetgroup":"Within ...

# %% [markdown]
# Interesting. Before the act, 50% of the complaints resolved in exonirating the officer or being unsubstantiated, both leading to the officer to be free of the charge.
#
# This number went down to almost 5% after the act. Instead, 56% of the complaints now are 'truncated'. A truncated allegation can result in four general outcomes:"
# 1. An allegation is closed as complaint withdrawn when the complainant voluntarily withdraws the complaint.
# 2. An allegation is closed as complainant/victim/witness unavailable when the complainant, victim and/or witness cannot be located after multiple and varied attempts (This also includes complaints in which the complainant is incarcerated and the attorney advises no contact).
# 3. An allegation is closed as complainant/victim/witness uncooperative when the participation of the complainant, victim and/or witness is insufficient to enable the board to conduct a full investigation.
# 4. An allegation is closed as victim unidentified when the board is unable to identify the victim."
#
# All of the outcomes are quite similar with regards to penalizing the officer named in the complaint, which is that they don't get penalized.
# Moreover, the % of complaints substantiated (only one in favor of the complainant) seems to remain the same.

# %% [markdown]
# ## Conclusion
#
# I started this analysis with the hypothesis that the Act has been associated with changes in trends of complaints against police officers, particularly that it increased overall complaints and especially substantiated complaints against police officers.
#
# However, I found little evidence to that. The only significant findings were:
# - Complaints on Abuse of Authority significantly decreased around 2021-2023, relative to others
# - There are less complaints that are unsubstantiated or resolved in exonirating the officer, but there are much more 'truncated' ones. Which don't seem to be much different with regards to penalizing officers named in the complaint.
